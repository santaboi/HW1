# %%
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.datasets import cifar10
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
import tensorflow as tf
import tensorflow_datasets.public_api as tfds
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline
matplotlib.rcParams['figure.facecolor'] = '#ffffff'
(train_imgs, train_lbls), (test_imgs, test_lbls) = tfds.load('cifar10', split=['train', 'test'], as_supervised=True)
#categorize each labels
train_lbls = to_categorical(train_lbls, 10)
test_lbls = to_categorical(test_lbls, 10)
#change types
train_imgs = train_imgs.astype(np.float32)
test_imgs = test_imgs.astype(np.float32)
# Out:
# ...
# Dl Completed...: 0 url [00:00, ? url/s]
# ...
# Dl Completed...: 100%|██████████| 1/1 [01:19<00:00, 79.65s/ url]
#
# ...
# Dl Completed...: 100%|██████████| 1/1 [01:22<00:00, 82.05s/ url]
# Dataset cifar10 downloaded and prepared to C:\Users\user\AppData\Roaming\SPB_16.6\tensorflow_datasets\cifar10\3.0.2. Subsequent calls will reuse this data.

# %%
"""def cifardata_loading():
    (train_imgs , train_lbls) , (test_imgs , test_lbls) = cifar10.load_data()
    #categorize each labels
    train_lbls = to_categorical(train_lbls , 10)
    test_lbls= to_categorical(test_lbls , 10)
    #change types
    train_imgs = train_imgs.astype(np.float32)
    test_imgs = test_imgs.astype(np.float32)

    #may_modified
    #(train_imgs , test_imgs) = normalization(train_imgs , test_imgs)
    return train_imgs , test_imgs"""

# %%
for img in train_imgs:
    plt.imshow()
    break
# Out:
# tf.Tensor(7, shape=(), dtype=int64)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# C:\Users\user\AppData\Local\Temp/ipykernel_19616/2567492829.py in <module>
#       7 for img in train_ds :
#       8     print(img[1])
# ----> 9     cv2.imshow('!' , img)
#      10     break
#
# TypeError: mat is not a numerical tuple
